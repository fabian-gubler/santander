# %%
import pandas as pd 
import numpy as np 

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import warnings
warnings.filterwarnings('ignore')

# %%
nn = pd.read_csv("/Users/kaanaydin/Desktop/Blending/submission_nn_fe1_sum_final.csv")
lgbm = pd.read_csv("/Users/kaanaydin/Desktop/Blending/submission_lgbm_fe1_sum_final.csv")
sub = pd.read_csv("/Users/kaanaydin/Desktop/Blending/sample_submission.csv")

# %%
lgbm = pd.read_csv("/content/drive/MyDrive/Data Science Project - Team D/submission/submission_lgbm_fe1_sum_final
lgbm = pd.read_csv("/content/drive/MyDrive/Data Science Project - Team D/submission/##########")
sub = pd.read_csv("/content/drive/MyDrive/Data Science Project - Team D/data/raw-data/sample_submission.csv)

# %%
lgbm_ratio = 5

nn_ratio = 1
sum = lgbm_ratio + nn_ratio

sub["target"] = nn["target"]*nn_ratio + lgbm["target"]*lgbm_ratio
sub["target"] = sub["target"]/sum

sub.to_csv("blendtry.csv", index=False)
